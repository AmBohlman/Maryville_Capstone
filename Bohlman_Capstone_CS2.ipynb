# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
file_path = "/updated_pollution_dataset.csv"
air_data = pd.read_csv(file_path)
air_data.head()
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate
# 3                           11.1                 551        Good
# 4                           12.7                 303        Good

# %%
air_data['record_ID'] = air_data.index
air_data.rename(columns={'Proximity_to_Industrial_Areas': 'industry_Proximity', 'Air Quality': 'air_Quality','Population_Density': 'population_Density', 'Temperature': 'temp','Humidity': 'humidity'}, inplace=True)
air_data = air_data[['record_ID', 'temp', 'humidity', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO','industry_Proximity', 'population_Density', 'air_Quality']]
air_data.drop_duplicates(inplace=True)
air_data.dropna(inplace=True)
air_data.head()
# Out:
#    record_ID  temp  humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0          0  29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1          1  28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2          2  23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3          3  27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4          4  26.5      70.7    6.9  16.0  21.9   5.6  1.01
#
#    industry_Proximity  population_Density air_Quality
# 0                 6.3                 319    Moderate
# 1                 6.0                 611    Moderate
# 2                 5.2                 619    Moderate
# 3                11.1                 551        Good
# 4                12.7                 303        Good

# %%
air_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   record_ID           5000 non-null   int64
#  1   temp                5000 non-null   float64
#  2   humidity            5000 non-null   float64
#  3   PM2.5               5000 non-null   float64
#  4   PM10                5000 non-null   float64
#  5   NO2                 5000 non-null   float64
#  6   SO2                 5000 non-null   float64
#  7   CO                  5000 non-null   float64
#  8   industry_Proximity  5000 non-null   float64
#  9   population_Density  5000 non-null   int64
#  10  air_Quality         5000 non-null   object
# dtypes: float64(8), int64(2), object(1)
# memory usage: 429.8+ KB

# %%
label = air_data['air_Quality']
features = air_data.drop('air_Quality', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
best_score = 0
best_n = 0
for n in range(1, 11):
  model = KNeighborsClassifier(n_neighbors = n)
  model.fit(X_train, y_train)
  score = model.score(X_train, y_train)
  if score > best_score:
    best_score = score
    best_n = n
print(f'Best n: {best_n}')
print(f'Best score: {best_score}')
# Out:
# Best n: 1
# Best score: 1.0

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 1.0

# %%
file_path = "/Measurement_summary.csv"
air_big_data = pd.read_csv(file_path)
air_big_data.head()
# Out:
#    Measurement date  Station code  \
# 0  2017-01-01 00:00           101
# 1  2017-01-01 01:00           101
# 2  2017-01-01 02:00           101
# 3  2017-01-01 03:00           101
# 4  2017-01-01 04:00           101
#
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
#
#      SO2    NO2     O3   CO  PM10  PM2.5
# 0  0.004  0.059  0.002  1.2  73.0   57.0
# 1  0.004  0.058  0.002  1.2  71.0   59.0
# 2  0.004  0.056  0.002  1.2  70.0   59.0
# 3  0.004  0.056  0.002  1.2  70.0   58.0
# 4  0.003  0.051  0.002  1.2  69.0   61.0

# %%
air_big_data.info()
air_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227666 entries, 0 to 227665
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Measurement date  227666 non-null  object
#  1   Station code      227666 non-null  int64
#  2   Address           227665 non-null  object
#  3   Latitude          227665 non-null  float64
#  4   Longitude         227665 non-null  float64
#  5   SO2               227665 non-null  float64
#  6   NO2               227665 non-null  float64
#  7   O3                227665 non-null  float64
#  8   CO                227665 non-null  float64
#  9   PM10              227665 non-null  float64
#  10  PM2.5             227665 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 19.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   record_ID           5000 non-null   int64
#  1   temp                5000 non-null   float64
#  2   humidity            5000 non-null   float64
#  3   PM2.5               5000 non-null   float64
#  4   PM10                5000 non-null   float64
#  5   NO2                 5000 non-null   float64
#  6   SO2                 5000 non-null   float64
#  7   CO                  5000 non-null   float64
#  8   industry_Proximity  5000 non-null   float64
#  9   population_Density  5000 non-null   int64
#  10  air_Quality         5000 non-null   object
# dtypes: float64(8), int64(2), object(1)
# memory usage: 429.8+ KB

# %%
air_big_data['record_ID'] = air_big_data.index
seoul_air_shaped = air_big_data[['record_ID','SO2','NO2','PM2.5','PM10', 'CO']]
pollution_shaped = air_data[['record_ID', 'SO2', 'NO2', 'PM2.5', 'PM10', 'CO', 'air_Quality']]

# %%
label = pollution_shaped['air_Quality']
features = pollution_shaped.drop('air_Quality', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_train, y_train)
predictions = model.predict(seoul_air_shaped)
air_big_data['air_Quality'] = predictions

# %%
seoul_air_shaped.sample(5, random_state= 4)
# Out:
#         record_ID    SO2    NO2  PM2.5  PM10   CO
# 203513     203513  0.005  0.014   19.0  19.0  0.7
# 181127     181127  0.005  0.051   48.0  62.0  1.1
# 147961     147961  0.004  0.021   13.0  36.0  0.4
# 30924       30924  0.002  0.016   12.0  19.0  0.4
# 15322       15322  0.003  0.010   10.0  17.0  0.4

# %%
pollution_shaped.sample(5)
# Out:
#       record_ID   SO2   NO2  PM2.5  PM10    CO air_Quality
# 407         407   5.2  20.3    9.7  14.7  1.07        Good
# 1430       1430  18.9  27.6    5.9  21.1  1.82        Poor
# 1161       1161  17.0  39.2    2.2   7.8  2.00        Poor
# 1031       1031   9.9  26.3   17.5  22.8  1.61    Moderate
# 2817       2817   5.2  30.4   10.0  18.0  1.57    Moderate

# %%
#air_big_data.to_csv('seoul_data.csv', index=False)

# %%
air_big_data.sample(15)
# Out:
#         Measurement date  Station code  \
# 146031  2018-11-20 19:00           106
# 173865  2019-02-09 05:00           107
# 98704   2019-06-05 20:00           104
# 110070  2017-09-27 04:00           105
# 200202  2019-02-27 19:00           108
# 146372  2018-12-05 00:00           106
# 163296  2017-11-25 19:00           107
# 167678  2018-05-27 09:00           107
# 13880   2018-08-02 08:00           101
# 199431  2019-01-26 16:00           108
# 42254   2018-11-13 05:00           102
# 103411  2019-12-23 17:00           104
# 206207  2019-11-20 13:00           108
# 41142   2018-09-27 21:00           102
# 987     2017-02-11 03:00           101
#
#                                                   Address   Latitude  \
# 146031  10, Poeun-ro 6-gil, Mapo-gu, Seoul, Republic o...  37.555580
# 173865  18, Ttukseom-ro 3-gil, Seongdong-gu, Seoul, Re...  37.541864
# 98704   215, Jinheung-ro, Eunpyeong-gu, Seoul, Republi...  37.609823
# 110070  32, Segeomjeong-ro 4-gil, Seodaemun-gu, Seoul,...  37.593742
# 200202  571, Gwangnaru-ro, Gwangjin-gu, Seoul, Republi...  37.547180
# 146372  10, Poeun-ro 6-gil, Mapo-gu, Seoul, Republic o...  37.555580
# 163296  18, Ttukseom-ro 3-gil, Seongdong-gu, Seoul, Re...  37.541864
# 167678  18, Ttukseom-ro 3-gil, Seongdong-gu, Seoul, Re...  37.541864
# 13880   19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 199431  571, Gwangnaru-ro, Gwangjin-gu, Seoul, Republi...  37.547180
# 42254   15, Deoksugung-gil, Jung-gu, Seoul, Republic o...  37.564263
# 103411  215, Jinheung-ro, Eunpyeong-gu, Seoul, Republi...  37.609823
# 206207  571, Gwangnaru-ro, Gwangjin-gu, Seoul, Republi...  37.547180
# 41142   15, Deoksugung-gil, Jung-gu, Seoul, Republic o...  37.564263
# 987     19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
#
#          Longitude    SO2    NO2     O3   CO  PM10  PM2.5  record_ID  \
# 146031  126.905597  0.006  0.045  0.007  0.5  63.0   17.0     146031
# 173865  127.049659  0.003  0.010  0.029  0.4  30.0   13.0     173865
# 98704   126.934848  0.005  0.056  0.038  0.5  93.0   64.0      98704
# 110070  126.949679  0.006  0.021  0.039  0.5  52.0   33.0     110070
# 200202  127.092493  0.009  0.051  0.020  0.9  68.0   47.0     200202
# 146372  126.905597  0.003  0.016  0.020  0.3  26.0    3.0     146372
# 163296  127.049659  0.005  0.044  0.005  0.5  14.0    7.0     163296
# 167678  127.049659  0.007  0.023  0.036  0.4  71.0   31.0     167678
# 13880   127.005008  0.004  0.027  0.028  0.4  21.0   13.0      13880
# 199431  127.092493  0.004  0.025  0.022  0.7  47.0   17.0     199431
# 42254   126.974676  0.003  0.039  0.002  0.8  32.0   20.0      42254
# 103411  126.934848  0.002  0.017  0.026  0.7  35.0   23.0     103411
# 206207  127.092493  0.002  0.025  0.015  0.7  23.0   11.0     206207
# 41142   126.974676  0.002  0.027  0.014  0.4  13.0    8.0      41142
# 987     127.005008  0.003  0.008  0.031  0.3  25.0   14.0        987
#
#        air_Quality
# 146031        Good
# 173865        Good
# 98704         Good
# 110070    Moderate
# 200202        Good
# 146372        Good
# 163296        Good
# 167678        Good
# 13880         Good
# 199431    Moderate
# 42254         Good
# 103411        Good
# 206207        Good
# 41142         Good
# 987           Good

# %%
air_big_data.groupby('Station code').value_counts()
# Out:
# Station code  Measurement date  Address                                                            Latitude   Longitude   SO2    NO2    O3     CO   PM10  PM2.5  record_ID  air_Quality
# 101           2017-01-01 00:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republic of Korea          37.572016  127.005008  0.004  0.059  0.002  1.2  73.0  57.0   0          Good           1
#               2017-01-01 01:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republic of Korea          37.572016  127.005008  0.004  0.058  0.002  1.2  71.0  59.0   1          Good           1
#               2017-01-01 02:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republic of Korea          37.572016  127.005008  0.004  0.056  0.002  1.2  70.0  59.0   2          Good           1
#               2017-01-01 03:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republic of Korea          37.572016  127.005008  0.004  0.056  0.002  1.2  70.0  58.0   3          Good           1
#               2017-01-01 04:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republic of Korea          37.572016  127.005008  0.003  0.051  0.002  1.2  69.0  61.0   4          Good           1
#                                                                                                                                                                                           ..
# 109           2019-05-13 06:00  43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul, Republic of Korea  37.575743  127.028885  0.005  0.061  0.006  0.7  60.0  43.0   227660     Good           1
#               2019-05-13 07:00  43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul, Republic of Korea  37.575743  127.028885  0.005  0.059  0.011  0.8  60.0  43.0   227661     Good           1
#               2019-05-13 08:00  43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul, Republic of Korea  37.575743  127.028885  0.005  0.062  0.019  0.7  65.0  45.0   227662     Good           1
#               2019-05-13 09:00  43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul, Republic of Korea  37.575743  127.028885  0.005  0.059  0.028  0.6  58.0  39.0   227663     Good           1
#               2019-05-13 10:00  43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul, Republic of Korea  37.575743  127.028885  0.005  0.056  0.029  0.7  61.0  37.0   227664     Good           1
# Name: count, Length: 227665, dtype: int64
